# %% [markdown]
# # Installations

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

sns.set_style('darkgrid')
# %matplotlib inline

# %%
pd.__version__
# Out:
# '1.5.2'

# %% [markdown]
# # Read CSV

# %%
df = pd.read_csv('./data/gapminder.tsv',sep="\t")
df
# Out:
#           country continent  year  lifeExp       pop   gdpPercap
# 0     Afghanistan      Asia  1952   28.801   8425333  779.445314
# 1     Afghanistan      Asia  1957   30.332   9240934  820.853030
# 2     Afghanistan      Asia  1962   31.997  10267083  853.100710
# 3     Afghanistan      Asia  1967   34.020  11537966  836.197138
# 4     Afghanistan      Asia  1972   36.088  13079460  739.981106
# ...           ...       ...   ...      ...       ...         ...
# 1699     Zimbabwe    Africa  1987   62.351   9216418  706.157306
# 1700     Zimbabwe    Africa  1992   60.377  10704340  693.420786
# 1701     Zimbabwe    Africa  1997   46.809  11404948  792.449960
# 1702     Zimbabwe    Africa  2002   39.989  11926563  672.038623
# 1703     Zimbabwe    Africa  2007   43.487  12311143  469.709298
#
# [1704 rows x 6 columns]

# %%
df.head(5)
# Out:
#        country continent  year  lifeExp       pop   gdpPercap
# 0  Afghanistan      Asia  1952   28.801   8425333  779.445314
# 1  Afghanistan      Asia  1957   30.332   9240934  820.853030
# 2  Afghanistan      Asia  1962   31.997  10267083  853.100710
# 3  Afghanistan      Asia  1967   34.020  11537966  836.197138
# 4  Afghanistan      Asia  1972   36.088  13079460  739.981106

# %%
# Header

print(f"columns: {df.columns}")
# Out:
# columns: Index(['country', 'continent', 'year', 'lifeExp', 'pop', 'gdpPercap'], dtype='object')

# %%
df.sample(5)
# Out:
#          country continent  year  lifeExp       pop     gdpPercap
# 1637   Venezuela  Americas  1977   67.456  13503563  13143.950950
# 54     Argentina  Americas  1982   69.942  29341374   8997.897412
# 1106   Nicaragua  Americas  1962   48.632   1590597   3634.364406
# 961   Mauritania    Africa  1957   42.338   1076852    846.120261
# 766       Israel      Asia  2002   79.696   6029529  21905.595140

# %%
df.tail()
# Out:
#        country continent  year  lifeExp       pop   gdpPercap
# 1699  Zimbabwe    Africa  1987   62.351   9216418  706.157306
# 1700  Zimbabwe    Africa  1992   60.377  10704340  693.420786
# 1701  Zimbabwe    Africa  1997   46.809  11404948  792.449960
# 1702  Zimbabwe    Africa  2002   39.989  11926563  672.038623
# 1703  Zimbabwe    Africa  2007   43.487  12311143  469.709298

# %%
# Columns

df.columns
# Out:
# Index(['country', 'continent', 'year', 'lifeExp', 'pop', 'gdpPercap'], dtype='object')

# %%
# Values

df.values
# Out:
# array([['Afghanistan', 'Asia', 1952, 28.801, 8425333, 779.4453145],
#        ['Afghanistan', 'Asia', 1957, 30.332, 9240934, 820.8530296],
#        ['Afghanistan', 'Asia', 1962, 31.997, 10267083, 853.10071],
#        ...,
#        ['Zimbabwe', 'Africa', 1997, 46.809, 11404948, 792.4499603],
#        ['Zimbabwe', 'Africa', 2002, 39.989, 11926563, 672.0386227],
#        ['Zimbabwe', 'Africa', 2007, 43.487, 12311143, 469.7092981]],
#       dtype=object)

# %%
# Index

df.index
# Out:
# RangeIndex(start=0, stop=1704, step=1)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1704 entries, 0 to 1703
# Data columns (total 6 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   country    1704 non-null   object
#  1   continent  1704 non-null   object
#  2   year       1704 non-null   int64
#  3   lifeExp    1704 non-null   float64
#  4   pop        1704 non-null   int64
#  5   gdpPercap  1704 non-null   float64
# dtypes: float64(2), int64(2), object(2)
# memory usage: 80.0+ KB

# %%
print(f"{df.dtypes}")

print(f"shape: {df.shape}")

print(f"total items: {df.size}")
# Out:
# country       object
# continent     object
# year           int64
# lifeExp      float64
# pop            int64
# gdpPercap    float64
# dtype: object
# shape: (1704, 6)
# total items: 10224

# %% [markdown]
# # Types

# %%
type(df)
# Out:
# pandas.core.frame.DataFrame

# %%
type(df['country'])
# Out:
# pandas.core.series.Series

# %% [markdown]
# # specific columns

# %%
df['country']
# Out:
# 0       Afghanistan
# 1       Afghanistan
# 2       Afghanistan
# 3       Afghanistan
# 4       Afghanistan
#            ...
# 1699       Zimbabwe
# 1700       Zimbabwe
# 1701       Zimbabwe
# 1702       Zimbabwe
# 1703       Zimbabwe
# Name: country, Length: 1704, dtype: object

# %% [markdown]
# # subset of columns

# %%
df[['country','year']]
# Out:
#           country  year
# 0     Afghanistan  1952
# 1     Afghanistan  1957
# 2     Afghanistan  1962
# 3     Afghanistan  1967
# 4     Afghanistan  1972
# ...           ...   ...
# 1699     Zimbabwe  1987
# 1700     Zimbabwe  1992
# 1701     Zimbabwe  1997
# 1702     Zimbabwe  2002
# 1703     Zimbabwe  2007
#
# [1704 rows x 2 columns]

# %% [markdown]
# # loc and iloc Difference

# %%
df.loc[1701]
# Out:
# country       Zimbabwe
# continent       Africa
# year              1997
# lifeExp         46.809
# pop           11404948
# gdpPercap    792.44996
# Name: 1701, dtype: object

# %%
df.loc[[1,4,5,1701]]
# Out:
#           country continent  year  lifeExp       pop   gdpPercap
# 1     Afghanistan      Asia  1957   30.332   9240934  820.853030
# 4     Afghanistan      Asia  1972   36.088  13079460  739.981106
# 5     Afghanistan      Asia  1977   38.438  14880372  786.113360
# 1701     Zimbabwe    Africa  1997   46.809  11404948  792.449960

# %%
# Index based

df.iloc[1701]
# Out:
# country       Zimbabwe
# continent       Africa
# year              1997
# lifeExp         46.809
# pop           11404948
# gdpPercap    792.44996
# Name: 1701, dtype: object

# %%
df.iloc[[-1,-2]]
# Out:
#        country continent  year  lifeExp       pop   gdpPercap
# 1703  Zimbabwe    Africa  2007   43.487  12311143  469.709298
# 1702  Zimbabwe    Africa  2002   39.989  11926563  672.038623

# %%
df.iloc[-1]
# Out:
# country        Zimbabwe
# continent        Africa
# year               2007
# lifeExp          43.487
# pop            12311143
# gdpPercap    469.709298
# Name: 1703, dtype: object

# %%
df.loc[-1]
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# File ~/miniconda3/envs/torchenv/lib/python3.10/site-packages/pandas/core/indexes/range.py:391, in RangeIndex.get_loc(self, key, method, tolerance)
#     390 try:
# --> 391     return self._range.index(new_key)
#     392 except ValueError as err:
#
# ValueError: -1 is not in range
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[22], line 1
# ----> 1 df.loc[-1]
#
# File ~/miniconda3/envs/torchenv/lib/python3.10/site-packages/pandas/core/indexing.py:1073, in _LocationIndexer.__getitem__(self, key)
#    1070 axis = self.axis or 0
#    1072 maybe_callable = com.apply_if_callable(key, self.obj)
# -> 1073 return self._getitem_axis(maybe_callable, axis=axis)
#
# ...

# %% [markdown]
# # Filtering

# %%
df['country']=="Zimbabwe"

# %%
df.loc[df['country']=="Zimbabwe"]

# %% [markdown]
# # give multiple columns

# %%
df.loc[(df["country"] == "Zimbabwe") & (df["year"] > 1990), :]

# %% [markdown]
# # Sql transformers

# %%
df.groupby("year")['lifeExp'].agg(['mean','median','min','max','sum','prod'])

# %%
df.groupby("year")['lifeExp'].agg(np.std)

# %%
type(df.groupby("year"))

# %%
type(df.groupby("year")["lifeExp"])

# %%
df.groupby(["year", "continent"])[["lifeExp", "gdpPercap", "pop"]].agg([np.mean, np.std])

# %% [markdown]
# # Exercise
#
# #### Play Sql joins with table[1,2,3,4a,4b] csv

# %% [markdown]
# **long tail and fat matrix**

# %%
pew = pd.read_csv('./data/pew.csv')
pew

# %%
df.shape

# %%
pew.melt(
    id_vars='religion',  # we don't want to change,
    var_name='income',   # rest of all columns 
    value_name='count'   # their co-responding values
)

# %% [markdown]
# # Yearly Survey

# %%
billboard = pd.read_csv('./data/billboard.csv')
print(f"shape: {billboard.shape}")
billboard.sample(3)
# Out:
# shape: (317, 81)
#      year          artist      track  time date.entered  wk1   wk2   wk3  \
# 235  2000    Price, Kelly  As We Lay  6:20   2000-07-15   82  69.0  69.0
# 3    2000    3 Doors Down      Loser  4:24   2000-10-21   76  76.0  72.0
# 199  2000  McEntire, Reba    I'll Be  4:23   2000-05-13   89  79.0  79.0
#
#       wk4   wk5  ...  wk67  wk68  wk69  wk70  wk71  wk72  wk73  wk74  wk75  \
# 235  64.0  71.0  ...   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# 3    69.0  67.0  ...   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# 199  72.0  69.0  ...   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
#
#      wk76
# 235   NaN
# 3     NaN
# 199   NaN
#
# [3 rows x 81 columns]

# %%
billboard.columns
# Out:
# Index(['year', 'artist', 'track', 'time', 'date.entered', 'wk1', 'wk2', 'wk3',
#        'wk4', 'wk5', 'wk6', 'wk7', 'wk8', 'wk9', 'wk10', 'wk11', 'wk12',
#        'wk13', 'wk14', 'wk15', 'wk16', 'wk17', 'wk18', 'wk19', 'wk20', 'wk21',
#        'wk22', 'wk23', 'wk24', 'wk25', 'wk26', 'wk27', 'wk28', 'wk29', 'wk30',
#        'wk31', 'wk32', 'wk33', 'wk34', 'wk35', 'wk36', 'wk37', 'wk38', 'wk39',
#        'wk40', 'wk41', 'wk42', 'wk43', 'wk44', 'wk45', 'wk46', 'wk47', 'wk48',
#        'wk49', 'wk50', 'wk51', 'wk52', 'wk53', 'wk54', 'wk55', 'wk56', 'wk57',
#        'wk58', 'wk59', 'wk60', 'wk61', 'wk62', 'wk63', 'wk64', 'wk65', 'wk66',
#        'wk67', 'wk68', 'wk69', 'wk70', 'wk71', 'wk72', 'wk73', 'wk74', 'wk75',
#        'wk76'],
#       dtype='object')

# %%
# data scients need long tail matrix but shape explode

billboard_melt = billboard.melt(
    id_vars=['year','artist','track','time','date.entered'],
    var_name='week',
    value_name='rating'
)

billboard_melt
# Out:
#        year            artist                    track  time date.entered  \
# 0      2000             2 Pac  Baby Don't Cry (Keep...  4:22   2000-02-26
# 1      2000           2Ge+her  The Hardest Part Of ...  3:15   2000-09-02
# 2      2000      3 Doors Down               Kryptonite  3:53   2000-04-08
# 3      2000      3 Doors Down                    Loser  4:24   2000-10-21
# 4      2000          504 Boyz            Wobble Wobble  3:35   2000-04-15
# ...     ...               ...                      ...   ...          ...
# 24087  2000       Yankee Grey     Another Nine Minutes  3:10   2000-04-29
# 24088  2000  Yearwood, Trisha          Real Live Woman  3:55   2000-04-01
# 24089  2000   Ying Yang Twins  Whistle While You Tw...  4:19   2000-03-18
# 24090  2000     Zombie Nation            Kernkraft 400  3:30   2000-09-02
# 24091  2000   matchbox twenty                     Bent  4:12   2000-04-29
#
#        week  rating
# 0       wk1    87.0
# 1       wk1    91.0
# ...

# %%
billboard_songs = billboard_melt[['year','artist','track','time']]
billboard_songs
# Out:
#        year            artist                    track  time
# 0      2000             2 Pac  Baby Don't Cry (Keep...  4:22
# 1      2000           2Ge+her  The Hardest Part Of ...  3:15
# 2      2000      3 Doors Down               Kryptonite  3:53
# 3      2000      3 Doors Down                    Loser  4:24
# 4      2000          504 Boyz            Wobble Wobble  3:35
# ...     ...               ...                      ...   ...
# 24087  2000       Yankee Grey     Another Nine Minutes  3:10
# 24088  2000  Yearwood, Trisha          Real Live Woman  3:55
# 24089  2000   Ying Yang Twins  Whistle While You Tw...  4:19
# 24090  2000     Zombie Nation            Kernkraft 400  3:30
# 24091  2000   matchbox twenty                     Bent  4:12
#
# [24092 rows x 4 columns]

# %% [markdown]
# `note`: **24092 rows huge to store**

# %%
billboard_songs.drop_duplicates(inplace=True)
billboard_songs
# Out:
# /tmp/ipykernel_26739/1962376402.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   billboard_songs.drop_duplicates(inplace=True)
#      year            artist                    track  time
# 0    2000             2 Pac  Baby Don't Cry (Keep...  4:22
# 1    2000           2Ge+her  The Hardest Part Of ...  3:15
# 2    2000      3 Doors Down               Kryptonite  3:53
# 3    2000      3 Doors Down                    Loser  4:24
# 4    2000          504 Boyz            Wobble Wobble  3:35
# ..    ...               ...                      ...   ...
# 312  2000       Yankee Grey     Another Nine Minutes  3:10
# 313  2000  Yearwood, Trisha          Real Live Woman  3:55
# 314  2000   Ying Yang Twins  Whistle While You Tw...  4:19
# 315  2000     Zombie Nation            Kernkraft 400  3:30
# ...

# %%
billboard_songs['id'] = range( billboard_songs.shape[0] )
# Out:
# /tmp/ipykernel_26739/2921284478.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   billboard_songs['id'] = range( billboard_songs.shape[0] )

# %%
# billboard_songs.to_csv('billboard_songs.csv',index=False)

# %%
billboard_ratings = billboard_melt.merge(billboard_songs,on=['year','artist','track','time'])

billboard_ratings
# Out:
#        year           artist                    track  time date.entered  \
# 0      2000            2 Pac  Baby Don't Cry (Keep...  4:22   2000-02-26
# 1      2000            2 Pac  Baby Don't Cry (Keep...  4:22   2000-02-26
# 2      2000            2 Pac  Baby Don't Cry (Keep...  4:22   2000-02-26
# 3      2000            2 Pac  Baby Don't Cry (Keep...  4:22   2000-02-26
# 4      2000            2 Pac  Baby Don't Cry (Keep...  4:22   2000-02-26
# ...     ...              ...                      ...   ...          ...
# 24087  2000  matchbox twenty                     Bent  4:12   2000-04-29
# 24088  2000  matchbox twenty                     Bent  4:12   2000-04-29
# 24089  2000  matchbox twenty                     Bent  4:12   2000-04-29
# 24090  2000  matchbox twenty                     Bent  4:12   2000-04-29
# 24091  2000  matchbox twenty                     Bent  4:12   2000-04-29
#
#        week  rating   id
# 0       wk1    87.0    0
# 1       wk2    82.0    0
# ...

# %%
billboard_ratings[ ['id','time','date.entered', 'week', 'rating'] ]
# Out:
#         id  time date.entered  week  rating
# 0        0  4:22   2000-02-26   wk1    87.0
# 1        0  4:22   2000-02-26   wk2    82.0
# 2        0  4:22   2000-02-26   wk3    72.0
# 3        0  4:22   2000-02-26   wk4    77.0
# 4        0  4:22   2000-02-26   wk5    87.0
# ...    ...   ...          ...   ...     ...
# 24087  316  4:12   2000-04-29  wk72     NaN
# 24088  316  4:12   2000-04-29  wk73     NaN
# 24089  316  4:12   2000-04-29  wk74     NaN
# 24090  316  4:12   2000-04-29  wk75     NaN
# 24091  316  4:12   2000-04-29  wk76     NaN
#
# [24092 rows x 5 columns]

# %%
ebola = pd.read_csv('./data/country_timeseries.csv')
ebola
# Out:
#            Date  Day  Cases_Guinea  Cases_Liberia  Cases_SierraLeone  \
# 0      1/5/2015  289        2776.0            NaN            10030.0
# 1      1/4/2015  288        2775.0            NaN             9780.0
# 2      1/3/2015  287        2769.0         8166.0             9722.0
# 3      1/2/2015  286           NaN         8157.0                NaN
# 4    12/31/2014  284        2730.0         8115.0             9633.0
# ..          ...  ...           ...            ...                ...
# 117   3/27/2014    5         103.0            8.0                6.0
# 118   3/26/2014    4          86.0            NaN                NaN
# 119   3/25/2014    3          86.0            NaN                NaN
# 120   3/24/2014    2          86.0            NaN                NaN
# 121   3/22/2014    0          49.0            NaN                NaN
#
#      Cases_Nigeria  Cases_Senegal  Cases_UnitedStates  Cases_Spain  \
# 0              NaN            NaN                 NaN          NaN
# ...

# %%
ebola_long = ebola.melt(id_vars=['Date','Day'],value_name="cases")
ebola_long
# Out:
#             Date  Day      variable   cases
# 0       1/5/2015  289  Cases_Guinea  2776.0
# 1       1/4/2015  288  Cases_Guinea  2775.0
# 2       1/3/2015  287  Cases_Guinea  2769.0
# 3       1/2/2015  286  Cases_Guinea     NaN
# 4     12/31/2014  284  Cases_Guinea  2730.0
# ...          ...  ...           ...     ...
# 1947   3/27/2014    5   Deaths_Mali     NaN
# 1948   3/26/2014    4   Deaths_Mali     NaN
# 1949   3/25/2014    3   Deaths_Mali     NaN
# 1950   3/24/2014    2   Deaths_Mali     NaN
# 1951   3/22/2014    0   Deaths_Mali     NaN
#
# [1952 rows x 4 columns]

# %%
ebola_long['variable'].str.split('_',expand=True).rename(columns={0:"severity",1:"cases"})
# Out:
#      severity   cases
# 0       Cases  Guinea
# 1       Cases  Guinea
# 2       Cases  Guinea
# 3       Cases  Guinea
# 4       Cases  Guinea
# ...       ...     ...
# 1947   Deaths    Mali
# 1948   Deaths    Mali
# 1949   Deaths    Mali
# 1950   Deaths    Mali
# 1951   Deaths    Mali
#
# [1952 rows x 2 columns]

# %%
ebola_long['seviority'] = ebola_long['variable'].str.split('_').str.get(0)
ebola_long['Causes'] = ebola_long['variable'].str.split('_').str[1]

# %%
#del ebola_long['variable']

ebola_long.drop('variable',axis=1,inplace=True)

# %%
ebola_long
# Out:
#             Date  Day   cases seviority  Causes
# 0       1/5/2015  289  2776.0     Cases  Guinea
# 1       1/4/2015  288  2775.0     Cases  Guinea
# 2       1/3/2015  287  2769.0     Cases  Guinea
# 3       1/2/2015  286     NaN     Cases  Guinea
# 4     12/31/2014  284  2730.0     Cases  Guinea
# ...          ...  ...     ...       ...     ...
# 1947   3/27/2014    5     NaN    Deaths    Mali
# 1948   3/26/2014    4     NaN    Deaths    Mali
# 1949   3/25/2014    3     NaN    Deaths    Mali
# 1950   3/24/2014    2     NaN    Deaths    Mali
# 1951   3/22/2014    0     NaN    Deaths    Mali
#
# [1952 rows x 5 columns]

# %%
weather = pd.read_csv('./data/weather.csv')
weather
# Out:
#          id  year  month element    d1    d2    d3    d4    d5    d6  ...  \
# 0   MX17004  2010      1    tmax   NaN   NaN   NaN   NaN   NaN   NaN  ...
# 1   MX17004  2010      1    tmin   NaN   NaN   NaN   NaN   NaN   NaN  ...
# 2   MX17004  2010      2    tmax   NaN  27.3  24.1   NaN   NaN   NaN  ...
# 3   MX17004  2010      2    tmin   NaN  14.4  14.4   NaN   NaN   NaN  ...
# 4   MX17004  2010      3    tmax   NaN   NaN   NaN   NaN  32.1   NaN  ...
# 5   MX17004  2010      3    tmin   NaN   NaN   NaN   NaN  14.2   NaN  ...
# 6   MX17004  2010      4    tmax   NaN   NaN   NaN   NaN   NaN   NaN  ...
# 7   MX17004  2010      4    tmin   NaN   NaN   NaN   NaN   NaN   NaN  ...
# 8   MX17004  2010      5    tmax   NaN   NaN   NaN   NaN   NaN   NaN  ...
# 9   MX17004  2010      5    tmin   NaN   NaN   NaN   NaN   NaN   NaN  ...
# 10  MX17004  2010      6    tmax   NaN   NaN   NaN   NaN   NaN   NaN  ...
# 11  MX17004  2010      6    tmin   NaN   NaN   NaN   NaN   NaN   NaN  ...
# ...

# %%
sns.heatmap(weather.isna());
plt.xlabel("columns")
plt.ylabel("indexes")
plt.show()

# %%
weather_melt = weather.melt(
    id_vars=['id','year','month','element'],
    var_name='day',
    value_name='temperature'
)
weather_melt
# Out:
#           id  year  month element  day  temperature
# 0    MX17004  2010      1    tmax   d1          NaN
# 1    MX17004  2010      1    tmin   d1          NaN
# 2    MX17004  2010      2    tmax   d1          NaN
# 3    MX17004  2010      2    tmin   d1          NaN
# 4    MX17004  2010      3    tmax   d1          NaN
# ..       ...   ...    ...     ...  ...          ...
# 677  MX17004  2010     10    tmin  d31          NaN
# 678  MX17004  2010     11    tmax  d31          NaN
# 679  MX17004  2010     11    tmin  d31          NaN
# 680  MX17004  2010     12    tmax  d31          NaN
# 681  MX17004  2010     12    tmin  d31          NaN
#
# [682 rows x 6 columns]

# %%
# multi index format

weather_melt.pivot_table(
    index=['id','month','year','day'],
    columns="element",
    values="temperature" ,
    dropna=True
)
# Out:
# element                 tmax  tmin
# id      month year day
# MX17004 1     2010 d30  27.8  14.5
#         2     2010 d11  29.7  13.4
#                    d2   27.3  14.4
#                    d23  29.9  10.7
#                    d3   24.1  14.4
#         3     2010 d10  34.5  16.8
#                    d16  31.1  17.6
#                    d5   32.1  14.2
#         4     2010 d27  36.3  16.7
#         5     2010 d27  33.2  18.2
#         6     2010 d17  28.0  17.5
#                    d29  30.1  18.0
#         7     2010 d3   28.6  17.5
#                    d14  29.9  16.5
#         8     2010 d23  26.4  15.0
#                    d5   29.6  15.8
#                    d29  28.0  15.3
#                    d13  29.8  16.5
#                    d25  29.7  15.6
#                    d31  25.4  15.4
#                    d8   29.0  17.3
#         10    2010 d5   27.0  14.0
#                    d14  29.5  13.0
#                    d15  28.7  10.5
#                    d28  31.2  15.0
# ...

# %%
weather_melt.pivot_table(
    index=['id','month','year','day'],
    columns="element",
    values="temperature" ,
    dropna=True
).reset_index()
# Out:
# element       id  month  year  day  tmax  tmin
# 0        MX17004      1  2010  d30  27.8  14.5
# 1        MX17004      2  2010  d11  29.7  13.4
# 2        MX17004      2  2010   d2  27.3  14.4
# 3        MX17004      2  2010  d23  29.9  10.7
# 4        MX17004      2  2010   d3  24.1  14.4
# 5        MX17004      3  2010  d10  34.5  16.8
# 6        MX17004      3  2010  d16  31.1  17.6
# 7        MX17004      3  2010   d5  32.1  14.2
# 8        MX17004      4  2010  d27  36.3  16.7
# 9        MX17004      5  2010  d27  33.2  18.2
# 10       MX17004      6  2010  d17  28.0  17.5
# 11       MX17004      6  2010  d29  30.1  18.0
# 12       MX17004      7  2010   d3  28.6  17.5
# 13       MX17004      7  2010  d14  29.9  16.5
# 14       MX17004      8  2010  d23  26.4  15.0
# 15       MX17004      8  2010   d5  29.6  15.8
# 16       MX17004      8  2010  d29  28.0  15.3
# 17       MX17004      8  2010  d13  29.8  16.5
# 18       MX17004      8  2010  d25  29.7  15.6
# ...

# %% [markdown]
# # chaining of different methods
#         - comes by practice

# %%
df['gdpPercap']\
    .apply([np.mean,np.std,np.var])\
    .values
# Out:
# array([7.21532708e+03, 9.85745454e+03, 9.71694101e+07])

# %%
# create DataFrame
dat = pd.DataFrame({
    'a': [10, 20, 30],
    'b': [20, 30, 40]
})
dat
# Out:
#     a   b
# 0  10  20
# 1  20  30
# 2  30  40

# %%
def my_sq(x):
    return x ** 2

# %%
my_sq(4)
# Out:
# 16

# %%
def avg_2(x, y):
    """ Take the average of 2 numbers """
    return (x + y) / 2

# %%
avg_2(10,20)
# Out:
# 15.0

# %%
# ?avg_2
# Out:
# Signature: avg_2(x, y)
# Docstring: Take the average of 2 numbers
# File:      /tmp/ipykernel_26739/4131216759.py
# Type:      function

# %%
dat["a"]  # Series
# Out:
# 0    10
# 1    20
# 2    30
# Name: a, dtype: int64

# %%
dat["a"].apply(my_sq)
# Out:
# 0    100
# 1    400
# 2    900
# Name: a, dtype: int64

# %%
def my_exp(x, e):
    print(f"e={e} and x={x} in my_exp")
    return x ** e

# %%
def flip_exp(e, x):
    print(f"e={e} and x={x} in flip_exp")
    return my_exp(x, e)

# %%
dat["a"].apply(flip_exp, x=3)
# Out:
# e=10 and x=3 in flip_exp
# e=10 and x=3 in my_exp
# e=20 and x=3 in flip_exp
# e=20 and x=3 in my_exp
# e=30 and x=3 in flip_exp
# e=30 and x=3 in my_exp
# 0              59049
# 1         3486784401
# 2    205891132094649
# Name: a, dtype: int64

# %%
def avg_3_apply(col):
    return (np.mean(col))

# %%
dat.apply(avg_3_apply)
# Out:
# a    20.0
# b    30.0
# dtype: float64

# %%
def avg_3_apply(col):
    x = col[0]
    y = col[1]
    z = col[2]
    return (x + y + z) / 3

# %%
dat.apply(avg_3_apply)
# Out:
# a    20.0
# b    30.0
# dtype: float64

# %%
@np.vectorize
def v_avg_2_mod_np(x, y):
    if (x == 20):
        return np.NaN
    else:
        return (x + y) / 2

# %%
# %%timeit
v_avg_2_mod_np(dat['a'], dat['b'])
# Out:
# 33.6 µs ± 486 ns per loop (mean ± std. dev. of 7 runs, 10,000 loops each)

# %% [markdown]
# Early early days..
# - Numeric and Num_array specific for small array and astronamical arrays respectively
# - now Finance (Time Series)
# - scientific
# - numpy born
# - later pandas
# - etc...
#
#
# Numpy is tabular data (csv)      : homogenous
#
# Pandas is columnar data (parquet): heterogenous

# %%
rng  = np.random.RandomState(3)

ts = pd.Series(
    rng.normal(0,1,1000),
    index= pd.date_range('1-1-2000',periods=1000)
)

ts
# Out:
# 2000-01-01    1.788628
# 2000-01-02    0.436510
# 2000-01-03    0.096497
# 2000-01-04   -1.863493
# 2000-01-05   -0.277388
#                 ...
# 2002-09-22   -0.670745
# 2002-09-23    0.022502
# 2002-09-24    0.347617
# 2002-09-25    1.559960
# 2002-09-26   -0.503075
# Freq: D, Length: 1000, dtype: float64

# %%
rdf = pd.DataFrame(
    rng.normal(0,1,size=(1000,4)),
    index = ts.index,
    columns=['A','B','C','D']
)

rdf.head()
# Out:
#                    A         B         C         D
# 2000-01-01 -0.266849  1.352172  0.890849  1.841675
# 2000-01-02 -0.414863  1.654188 -0.122976 -0.327096
# 2000-01-03  0.018796 -1.741576  0.863437  0.716731
# 2000-01-04 -0.818269 -0.271366  1.316023 -0.110177
# 2000-01-05 -0.241435  0.647237 -0.143747 -1.131098

# %%
rdf.cumsum()
# Out:
#                     A          B         C         D
# 2000-01-01  -0.266849   1.352172  0.890849  1.841675
# 2000-01-02  -0.681712   3.006360  0.767874  1.514578
# 2000-01-03  -0.662916   1.264784  1.631311  2.231309
# 2000-01-04  -1.481184   0.993418  2.947334  2.121133
# 2000-01-05  -1.722620   1.640655  2.803587  0.990035
# ...               ...        ...       ...       ...
# 2002-09-22  11.302316 -11.406736 -0.810926 -5.404927
# 2002-09-23  10.169933 -11.123914 -0.420125 -4.827430
# 2002-09-24  10.147304 -12.410735  1.656281 -3.787904
# 2002-09-25  10.319697 -12.291873  1.857470 -4.259654
# 2002-09-26   9.600632 -13.855498  3.411850 -5.036027
#
# [1000 rows x 4 columns]

# %%
plt.rcParams['figure.figsize']=(19,6)
rdf.cumsum().plot();
plt.show()

# %%
dates = pd.date_range('20130101',periods=6)
dates
# Out:
# DatetimeIndex(['2013-01-01', '2013-01-02', '2013-01-03', '2013-01-04',
#                '2013-01-05', '2013-01-06'],
#               dtype='datetime64[ns]', freq='D')

# %%
df = pd.DataFrame(
    rng.normal(size=(6,4)),
    index=dates,
    columns=['rainfall','temp','humidty','windfall']
)
df
# Out:
#             rainfall      temp   humidty  windfall
# 2013-01-01 -0.642103  1.081388 -1.937863  1.032320
# 2013-01-02 -0.162458  0.006533 -1.124167 -0.455632
# 2013-01-03 -0.085020  1.054956 -0.953324 -2.236101
# 2013-01-04 -0.793162 -1.208318 -0.392292 -0.113846
# 2013-01-05  0.172664 -0.068498  0.764445 -1.600555
# 2013-01-06 -1.690603 -0.762614  0.147288  0.680543

# %%
df.describe().T
# Out:
#           count      mean       std       min       25%       50%       75%  \
# rainfall    6.0 -0.533447  0.671652 -1.690603 -0.755397 -0.402281 -0.104380
# temp        6.0  0.017241  0.930258 -1.208318 -0.589085 -0.030982  0.792850
# humidty     6.0 -0.582652  0.964464 -1.937863 -1.081456 -0.672808  0.012393
# windfall    6.0 -0.448878  1.272978 -2.236101 -1.314324 -0.284739  0.481946
#
#                max
# rainfall  0.172664
# temp      1.081388
# humidty   0.764445
# windfall  1.032320

# %%
mask = df.rainfall<0
mask
# Out:
# 2013-01-01     True
# 2013-01-02     True
# 2013-01-03     True
# 2013-01-04     True
# 2013-01-05    False
# 2013-01-06     True
# Freq: D, Name: rainfall, dtype: bool

# %%
df.loc[df.rainfall<0]
# Out:
#             rainfall      temp   humidty  windfall
# 2013-01-01 -0.642103  1.081388 -1.937863  1.032320
# 2013-01-02 -0.162458  0.006533 -1.124167 -0.455632
# 2013-01-03 -0.085020  1.054956 -0.953324 -2.236101
# 2013-01-04 -0.793162 -1.208318 -0.392292 -0.113846
# 2013-01-06 -1.690603 -0.762614  0.147288  0.680543

# %%
df.loc[df.rainfall<0,'rainfall']
# Out:
# 2013-01-01   -0.642103
# 2013-01-02   -0.162458
# 2013-01-03   -0.085020
# 2013-01-04   -0.793162
# 2013-01-06   -1.690603
# Name: rainfall, dtype: float64
